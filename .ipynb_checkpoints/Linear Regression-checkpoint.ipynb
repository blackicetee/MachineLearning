# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plt
import numpy as np

noise = 10 * np.random.randn(15) * 1.2
x = 10 * np.random.random(15,)-1

a = np.random.randint(2,15)
b = np.random.randint(2,15)

y_not_noisy = a + b * x
y_noisy = y_not_noisy + noise

y = y_noisy

def plotNoisyDataPoints():
    plt.plot(x, y, '*b', label='Data Points')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Noisy Data')
    plt.legend()
    plt.show()
    
plotNoisyDataPoints()

# %%
def create_hypothesis(theta_0, theta_1):
    def hypothesis(vector_x):
        return theta_0 + theta_1 * vector_x
    return hypothesis

def create_cost_function(linear_hypothesis, x_vector, y_vector):
    def cost_function(theta_0, theta_1):
        h = linear_hypothesis(theta_0, theta_1)
        m = len(x_vector)
        costs = (1. / 2 * m) * ((h(x_vector) - y_vector) ** 2).sum()
        return costs
    return cost_function

# %%
def plotHypothesis(theta_0, theta_1):
    h = create_hypothesis(theta_0, theta_1)
    plt.plot(x, y_noisy, '*b', label='Data Points')
    plt.plot(x, h(x), label='Hypothesis $h_\Theta$')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Hypothesis')
    plt.legend()
    plt.show()
    
plotHypothesis(2.,3.)

general_cf = create_cost_function(create_hypothesis, x, y)
specific_cf = general_cf(2.,3.)

print(specific_cf)
# Out:
# 253001.892107

# %%
ran = 4.
t0 = np.arange(a - ran, a + ran, ran * 0.05)
t1 = np.arange(b - ran, b + ran, ran * 0.05)
print(t0)
print (t1)

C = np.zeros([len(t0),len(t1)])
c = create_cost_function(create_hypothesis, x, y)

for i, t_0 in enumerate(t0):
    for j, t_1 in enumerate(t1):
        C[j][i] = c(t_0, t_1)

T0, T1 = np.meshgrid(t0, t1)
#121
plt.subplot(121)
plt.contour(T0, T1, C)
plt.xlabel('$\Theta_0$')
plt.ylabel('$\Theta_1$')
plt.title('Kostenfunktion')
plt.show()
# Out:
# [ 2.   2.2  2.4  2.6  2.8  3.   3.2  3.4  3.6  3.8  4.   4.2  4.4  4.6  4.8
#   5.   5.2  5.4  5.6  5.8  6.   6.2  6.4  6.6  6.8  7.   7.2  7.4  7.6  7.8
#   8.   8.2  8.4  8.6  8.8  9.   9.2  9.4  9.6  9.8]
# [  7.    7.2   7.4   7.6   7.8   8.    8.2   8.4   8.6   8.8   9.    9.2
#    9.4   9.6   9.8  10.   10.2  10.4  10.6  10.8  11.   11.2  11.4  11.6
#   11.8  12.   12.2  12.4  12.6  12.8  13.   13.2  13.4  13.6  13.8  14.
#   14.2  14.4  14.6  14.8]

# %%
def compute_new_theta(x, y, theta_0, theta_1, alpha):
    m = len(x)
    new_theta_0 = theta_0 - alpha * ((1/m) * (theta_0 + theta_1 * x - y).sum())
    new_theta_1 = theta_1 - alpha * ((1/m) * ((theta_0 + theta_1 * x - y) * x).sum())
    return new_theta_0, new_theta_1

def gradient_decent(x, y, theta_0, theta_1, alpha, decent_costs=[]):
    cost_function = create_cost_function(create_hypothesis, x, y)
    new_theta_0, new_theta_1 = compute_new_theta(x, y, theta_0, theta_1, alpha)
    decent =  cost_function(theta_0, theta_1) - cost_function(new_theta_0, new_theta_1)
    decent_costs.append(decent)
    if ((decent > 1) and (len(decent_costs) < 200)):
        return gradient_decent(x, y, new_theta_0, new_theta_1, alpha)
    return decent_costs, theta_0, theta_1
        
decent_costs, minimized_theta_0, minimized_theta_1 = gradient_decent(x, y, 2., 3., 0.01)
plotHypothesis(minimized_theta_0, minimized_theta_1)

# %%
def plotCostsToIterations(cost_list):
    i = len(cost_list)
    iterations = range(i)
    print(iterations)
    plt.plot(iterations, cost_list, '*b', label='Costs per iteration')
    plt.xlabel('iterations')
    plt.ylabel('costs')
    plt.title('Costs to iterations')
    plt.legend()
    plt.show()
    
plotCostsToIterations(decent_costs)
# Out:
# range(0, 19)

# %%
decent_costs, minimized_theta_0, minimized_theta_1 = gradient_decent(x, y, 2., 3., 0.00001)
plotHypothesis(minimized_theta_0, minimized_theta_1)
plotCostsToIterations(decent_costs)
# Out:
# range(0, 200)

# %%
decent_costs_001, minimized_theta_0_001, minimized_theta_1_001 = gradient_decent(x, y, 2., 3., 0.01)
plotHypothesis(minimized_theta_0_001, minimized_theta_1_001)
plotCostsToIterations(decent_costs_001)
# Out:
# range(0, 201)

# %%
decent_costs, minimized_theta_0, minimized_theta_1 = gradient_decent(x, y, 2., 3., 0.1)
plotHypothesis(minimized_theta_0, minimized_theta_1)
plotCostsToIterations(decent_costs)
# Out:
# range(0, 202)

# %%
decent_costs, minimized_theta_0, minimized_theta_1 = gradient_decent(x, y, 2., 3., 10)
plotHypothesis(minimized_theta_0, minimized_theta_1)
plotCostsToIterations(decent_costs)
# Out:
# range(0, 203)
